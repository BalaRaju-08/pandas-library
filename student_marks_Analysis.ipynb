# %%
import pandas as pd
df=pd.read_csv(r"c:\Users\Admin\Downloads\marksheet.csv")
print(df.to_string())
# Out:
#       id          Name  Gender  Age Section  Science  English  History  Maths
# 0      1       Bronnie  Female   13       C       21       81       62     49
# 1      2        Lemmie    Male   15       B       29       41       17     40
# 2      3         Danya  Female   14       C       12       87       16     96
# 3      4         Denna  Female   14       B       15       53       82     33
# 4      5       Jocelin    Male   14       A       43        6        3     21
# 5      6       Malissa  Female   14       C       98       51       85     76
# 6      7       Ichabod  Female   14       B       38       74       54     60
# 7      8      Beverlie    Male   14       B       25       51       41     80
# 8      9       Corrine    Male   15       A       39       16       22     49
# 9     10          Tate    Male   15       C       35       25       37     27
# 10    11          Dunn    Male   15       C      100       93       87     81
# ...

# %%
df.groupby("Gender")["Maths"].count()
# Out:
# Gender
# Female    100
# Male      100
# Name: Maths, dtype: int64

# %%
df.groupby("Gender")["Maths"].mean()
# Out:
# Gender
# Female    50.364407
# Male      55.386364
# Name: Maths, dtype: float64

# %%
df.groupby("Gender")["Maths"].max()
# Out:
# Gender
# Female    100
# Male      100
# Name: Maths, dtype: int64

# %%
df.groupby("Gender")["Maths"].min()
# Out:
# Gender
# Female    1
# Male      3
# Name: Maths, dtype: int64

# %%
df.groupby("Section")["Maths"].max()
# Out:
# Section
# A     97
# B    100
# C    100
# Name: Maths, dtype: int64

# %%
df.groupby("Section")["Maths"].min()
# Out:
# Section
# A    5
# B    1
# C    3
# Name: Maths, dtype: int64

# %%
female_students=df[df["Gender"]=="Female"]
print(female_students.to_string())
# Out:
#       id        Name  Gender  Age Section  Science  English  History  Maths
# 0      1     Bronnie  Female   13       C       21       81       62     49
# 2      3       Danya  Female   14       C       12       87       16     96
# 3      4       Denna  Female   14       B       15       53       82     33
# 5      6     Malissa  Female   14       C       98       51       85     76
# 6      7     Ichabod  Female   14       B       38       74       54     60
# 13    14      Gracie  Female   13       B       93       38       39     93
# 14    15       Missy  Female   13       B       98       18       84     74
# 17    18        Dory  Female   13       B        5       89       25     23
# 18    19     Opalina  Female   13       B       62       77       75     72
# 22    23       Merle  Female   13       C        5       83       19     39
# 23    24       Valma  Female   14       C       48       83       79     95
# ...

# %%
male=df[df["Gender"]=="Male"]
print(male.to_string())
# Out:
#       id          Name Gender  Age Section  Science  English  History  Maths
# 1      2        Lemmie   Male   15       B       29       41       17     40
# 4      5       Jocelin   Male   14       A       43        6        3     21
# 7      8      Beverlie   Male   14       B       25       51       41     80
# 8      9       Corrine   Male   15       A       39       16       22     49
# 9     10          Tate   Male   15       C       35       25       37     27
# 10    11          Dunn   Male   15       C      100       93       87     81
# 11    12       Valaria   Male   13       B       19        5       78     76
# 12    13       Merrick   Male   15       A       65       89       96     34
# 15    16      Gilberta   Male   15       A       53       30       90     64
# 16    17         Peggy   Male   13       A       91       45       44     45
# 19    20        Ashlan   Male   13       B       41        6       17      3
# ...

# %%
section=df[df["Section"]=="A"]
print(section.to_string())
# Out:
#       id          Name  Gender  Age Section  Science  English  History  Maths
# 4      5       Jocelin    Male   14       A       43        6        3     21
# 8      9       Corrine    Male   15       A       39       16       22     49
# 12    13       Merrick    Male   15       A       65       89       96     34
# 15    16      Gilberta    Male   15       A       53       30       90     64
# 16    17         Peggy    Male   13       A       91       45       44     45
# 20    21         Amery    Male   13       A       76       96       67     17
# 24    25          Jone    Male   14       A       17       87       16     50
# 25    26           Rae  Female   15       A       16       59       18     64
# 26    27      Charmine  Female   14       A       93       93       83     40
# 27    28         Hanan    Male   14       A       60       36       86     87
# 36    37          Josh  Female   14       A       54       23       19     94
# ...

# %%
print(df[df["Age"]>13].to_string())
# Out:
#       id          Name  Gender  Age Section  Science  English  History  Maths
# 1      2        Lemmie    Male   15       B       29       41       17     40
# 2      3         Danya  Female   14       C       12       87       16     96
# 3      4         Denna  Female   14       B       15       53       82     33
# 4      5       Jocelin    Male   14       A       43        6        3     21
# 5      6       Malissa  Female   14       C       98       51       85     76
# 6      7       Ichabod  Female   14       B       38       74       54     60
# 7      8      Beverlie    Male   14       B       25       51       41     80
# 8      9       Corrine    Male   15       A       39       16       22     49
# 9     10          Tate    Male   15       C       35       25       37     27
# 10    11          Dunn    Male   15       C      100       93       87     81
# 12    13       Merrick    Male   15       A       65       89       96     34
# ...

# %%
df[df["Maths"]>80]
# Out:
#       id        Name  Gender  Age Section  Science  English  History  Maths
# 2      3       Danya  Female   14       C       12       87       16     96
# 10    11        Dunn    Male   15       C      100       93       87     81
# 13    14      Gracie  Female   13       B       93       38       39     93
# 21    22     Benoite    Male   14       B        3       55       14     90
# 23    24       Valma  Female   14       C       48       83       79     95
# 27    28       Hanan    Male   14       A       60       36       86     87
# 29    30       Livia    Male   13       C       95       65       25     91
# 30    31      Richie  Female   15       B       14       83        9     90
# 36    37        Josh  Female   14       A       54       23       19     94
# 41    42       Hetty  Female   13       B       21       89       72     84
# 51    52      Rollie  Female   13       A       17       99       29     85
# ...

# %%
print(df[df["English"]<40].to_string())
# Out:
#       id       Name  Gender  Age Section  Science  English  History  Maths
# 4      5    Jocelin    Male   14       A       43        6        3     21
# 8      9    Corrine    Male   15       A       39       16       22     49
# 9     10       Tate    Male   15       C       35       25       37     27
# 11    12    Valaria    Male   13       B       19        5       78     76
# 13    14     Gracie  Female   13       B       93       38       39     93
# 14    15      Missy  Female   13       B       98       18       84     74
# 15    16   Gilberta    Male   15       A       53       30       90     64
# 19    20     Ashlan    Male   13       B       41        6       17      3
# 27    28      Hanan    Male   14       A       60       36       86     87
# 28    29     Adrian    Male   13       C       19        8       76     75
# 31    32  Ekaterina  Female   15       B       17       36       45     27
# ...

# %%
df[(df["Gender"]=="Female") & (df["Section"]=="A") ]
# Out:
#       id       Name  Gender  Age Section  Science  English  History  Maths
# 25    26        Rae  Female   15       A       16       59       18     64
# 26    27   Charmine  Female   14       A       93       93       83     40
# 36    37       Josh  Female   14       A       54       23       19     94
# 38    39       Adah  Female   13       A       71       90       78     35
# 46    47    Everett  Female   14       A       84       57       25     57
# 51    52     Rollie  Female   13       A       17       99       29     85
# 68    69        Nil  Female   15       A       84       97       70     96
# 86    87     Aubrey  Female   13       A        8       72       78     14
# 88    89      Ranee  Female   15       A       58       16       64     67
# 91    92      Daffi  Female   15       A       79       82       99     81
# 92    93   Morganne  Female   15       A       22       86        9     38
# ...

# %%
df[df["Science"]>90]
# Out:
#       id        Name  Gender  Age Section  Science  English  History  Maths
# 5      6     Malissa  Female   14       C       98       51       85     76
# 10    11        Dunn    Male   15       C      100       93       87     81
# 13    14      Gracie  Female   13       B       93       38       39     93
# 14    15       Missy  Female   13       B       98       18       84     74
# 16    17       Peggy    Male   13       A       91       45       44     45
# 26    27    Charmine  Female   14       A       93       93       83     40
# 29    30       Livia    Male   13       C       95       65       25     91
# 35    36  Anna-diane  Female   15       C       93       53       10     29
# 39    40      Luelle    Male   13       B      100       52       89     76
# 49    50      Karrie    Male   14       A       94       15       66     34
# 70    71         Bil  Female   15       C       95       32       91     48
# ...

# %%
print(df["Maths"].mean())
# Out:
# 53.016

# %%
print(df["Science"].max())
# Out:
# 100

# %%
print(df["English"].min())
# Out:
# 1

# %%
print(df[["Maths","English","Science"]].mean())
# Out:
# Maths      53.016
# English    47.980
# Science    51.440
# dtype: float64

# %%
print(df[["Maths","English"]].max())
# Out:
# Maths      100
# English    100
# dtype: int64

# %%
df.groupby("Gender")["Maths"].mean()
# Out:
# Gender
# Female    50.364407
# Male      55.386364
# Name: Maths, dtype: float64

# %%
df.groupby("Section")["Science"].max()
# Out:
# Section
# A    100
# B    100
# C    100
# Name: Science, dtype: int64

# %%
df.sort_values(by="Maths")
# Out:
#       id     Name  Gender  Age Section  Science  English  History  Maths
# 225  226    Blake  Female   15       B       16        4       49      1
# 130  131   Blisse  Female   15       B       85       30       50      2
# 19    20   Ashlan    Male   13       B       41        6       17      3
# 136  137   Ailene  Female   15       C       52       39       37      3
# 139  140    Ricky  Female   13       B       21       65       90      4
# ..   ...      ...     ...  ...     ...      ...      ...      ...    ...
# 61    62    Fanny  Female   13       C       49       90       13     98
# 123  124     Orin  Female   15       B       70       75       21     99
# 87    88  Sheffie  Female   15       C       44       55       51    100
# 76    77    David  Female   13       B       27        2       63    100
# 168  169   Ilaire    Male   14       C       95       56        4    100
#
# [250 rows x 9 columns]

# %%
df.sort_values(by="Maths",ascending=False)
# Out:
#       id     Name  Gender  Age Section  Science  English  History  Maths
# 76    77    David  Female   13       B       27        2       63    100
# 87    88  Sheffie  Female   15       C       44       55       51    100
# 168  169   Ilaire    Male   14       C       95       56        4    100
# 123  124     Orin  Female   15       B       70       75       21     99
# 61    62    Fanny  Female   13       C       49       90       13     98
# ..   ...      ...     ...  ...     ...      ...      ...      ...    ...
# 139  140    Ricky  Female   13       B       21       65       90      4
# 19    20   Ashlan    Male   13       B       41        6       17      3
# 136  137   Ailene  Female   15       C       52       39       37      3
# 130  131   Blisse  Female   15       B       85       30       50      2
# 225  226    Blake  Female   15       B       16        4       49      1
#
# [250 rows x 9 columns]

# %%
df.sort_values(by="English")
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths
# 57    58     Issie    Male   14       A       64        1       74      6
# 42    43   Brandie    Male   15       B       43        2       17     78
# 90    91      Linn    Male   13       C       23        2       42     43
# 76    77     David  Female   13       B       27        2       63    100
# 185  186    Alaine    Male   15       A       48        2       63     91
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 51    52    Rollie  Female   13       A       17       99       29     85
# 155  156     Sarah  Female   13       B       55       99        8     72
# 122  123  Brandise    Male   13       A       18      100       39      8
# 180  181   Davidde    Male   13       C       98      100       23     84
# 134  135   Humfrid  Female   13       B       96      100       42     62
#
# [250 rows x 9 columns]

# %%
df.sort_values("Maths",ascending=False).head(5)
# Out:
#       id     Name  Gender  Age Section  Science  English  History  Maths
# 76    77    David  Female   13       B       27        2       63    100
# 87    88  Sheffie  Female   15       C       44       55       51    100
# 168  169   Ilaire    Male   14       C       95       56        4    100
# 123  124     Orin  Female   15       B       70       75       21     99
# 61    62    Fanny  Female   13       C       49       90       13     98

# %%
df["Science"].tail(5)
# Out:
# 245    28
# 246     1
# 247    93
# 248    35
# 249    50
# Name: Science, dtype: int64

# %%
df["total"]=df["Science"]+df["Maths"]+df["English"]+df["History"]
df
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 1      2    Lemmie    Male   15       B       29       41       17     40
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 4      5   Jocelin    Male   14       A       43        6        3     21
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 245  246    Nickie    Male   13       C       28       15       25     10
# 246  247       Rog  Female   13       B        1        4       68     65
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
#      total
# 0      213
# 1      127
# 2      211
# 3      183
# 4       73
# ...

# %%
print(df["total"].max())
# Out:
# 361

# %%
df.sort_values("total",ascending=False).head(1)
# Out:
#     id  Name Gender  Age Section  Science  English  History  Maths  total  \
# 10  11  Dunn   Male   15       C      100       93       87     81    361
#
#       Avg
# 10  90.25

# %%
df["Avg"]=df["total"]/4

# %%
df
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 1      2    Lemmie    Male   15       B       29       41       17     40
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 4      5   Jocelin    Male   14       A       43        6        3     21
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 245  246    Nickie    Male   13       C       28       15       25     10
# 246  247       Rog  Female   13       B        1        4       68     65
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
#      total    Avg
# 0      213  53.25
# 1      127  31.75
# 2      211  52.75
# ...

# %%
df[df["total"]>300]
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 5      6   Malissa  Female   14       C       98       51       85     76
# 10    11      Dunn    Male   15       C      100       93       87     81
# 23    24     Valma  Female   14       C       48       83       79     95
# 26    27  Charmine  Female   14       A       93       93       83     40
# 39    40    Luelle    Male   13       B      100       52       89     76
# 68    69       Nil  Female   15       A       84       97       70     96
# 91    92     Daffi  Female   15       A       79       82       99     81
# 120  121  Patrizia    Male   13       A       79       88       96     93
# 149  150     Inger  Female   13       B       53       95       75     81
# 150  151    Herold    Male   13       A       92       97       62     69
# 178  179       Val    Male   13       B       95       73       91     61
# 180  181   Davidde    Male   13       C       98      100       23     84
# ...

# %%
df[df["Age"]>75]
# Out:
# Empty DataFrame
# Columns: [id, Name, Gender, Age, Section, Science, English, History, Maths, total, Avg]
# Index: []

# %%
df.groupby("Section")["total"].max()
# Out:
# Section
# A    356
# B    333
# C    361
# Name: total, dtype: int64

# %%
df.loc[df.groupby("Section")["total"].idxmax()]
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 120  121  Patrizia    Male   13       A       79       88       96     93
# 200  201    Ruddie  Female   15       B       84       97       88     64
# 10    11      Dunn    Male   15       C      100       93       87     81
#
#      total    Avg
# 120    356  89.00
# 200    333  83.25
# 10     361  90.25

# %%
a=df[(df["Gender"]=="Female")]
a
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 5      6   Malissa  Female   14       C       98       51       85     76
# 6      7   Ichabod  Female   14       B       38       74       54     60
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 238  239    Ashlin  Female   14       A       49       47       19     55
# 242  243    Morrie  Female   13       B       17       24       41     21
# 244  245  Jesselyn  Female   15       C       11       53       15     13
# 246  247       Rog  Female   13       B        1        4       68     65
# 248  249      Anni  Female   14       B       35       73       66     59
#
#      total    Avg
# 0      213  53.25
# 2      211  52.75
# 3      183  45.75
# ...

# %%
a.loc[a["total"].idxmax()]
# Out:
# id             69
# Name          Nil
# Gender     Female
# Age            15
# Section         A
# Science        84
# English        97
# History        70
# Maths          96
# total         347
# Avg         86.75
# Name: 68, dtype: object

# %%
mal=df[df["Gender"]=="Male"]
mal
# Out:
#       id      Name Gender  Age Section  Science  English  History  Maths  \
# 1      2    Lemmie   Male   15       B       29       41       17     40
# 4      5   Jocelin   Male   14       A       43        6        3     21
# 7      8  Beverlie   Male   14       B       25       51       41     80
# 8      9   Corrine   Male   15       A       39       16       22     49
# 9     10      Tate   Male   15       C       35       25       37     27
# ..   ...       ...    ...  ...     ...      ...      ...      ...    ...
# 241  242     Janey   Male   15       C        3       49       67     96
# 243  244   Domingo   Male   13       C       95       63       65     71
# 245  246    Nickie   Male   13       C       28       15       25     10
# 247  248      Kaia   Male   15       B       93       48       82     44
# 249  250  Fernande   Male   15       B       50        8       80     78
#
#      total    Avg
# 1      127  31.75
# 4       73  18.25
# 7      197  49.25
# ...

# %%
mal.loc[mal["total"].idxmax()]
# Out:
# id            11
# Name        Dunn
# Gender      Male
# Age           15
# Section        C
# Science      100
# English       93
# History       87
# Maths         81
# total        361
# Avg        90.25
# Name: 10, dtype: object

# %%
df.loc[df.groupby("Section")["Avg"].idxmax()]
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 120  121  Patrizia    Male   13       A       79       88       96     93
# 200  201    Ruddie  Female   15       B       84       97       88     64
# 10    11      Dunn    Male   15       C      100       93       87     81
#
#      total    Avg
# 120    356  89.00
# 200    333  83.25
# 10     361  90.25

# %%
df[df["Maths"]>35]
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 1      2    Lemmie    Male   15       B       29       41       17     40
# 2      3     Danya  Female   14       C       12       87       16     96
# 5      6   Malissa  Female   14       C       98       51       85     76
# 6      7   Ichabod  Female   14       B       38       74       54     60
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 243  244   Domingo    Male   13       C       95       63       65     71
# 246  247       Rog  Female   13       B        1        4       68     65
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
#      total    Avg
# 0      213  53.25
# 1      127  31.75
# 2      211  52.75
# ...

# %%
# which gender has the higher avg marks in science
df.groupby("Gender")["Science"].mean().idxmax()
# Out:
# 'Male'
